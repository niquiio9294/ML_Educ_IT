# %% [markdown]
# Ejemplo de lectura desde Excel
#
# conda install xlrd

# %%
import pandas as pd
archivo_excel = pd.read_excel('../DataSets/Terrenos Mendoza.xlsx')
print(archivo_excel.columns)

columnas = ['#', 'Luz', 'Agua', 'Gas', 'Cloacas', 'Suelo', 'Contexto urbano',
       'Permeabilidad', 'usd mt2', ' usd Total ', 'Superficie', 'Distrito',
       'Latitud', 'Longuitud', 'Derecho de agua', 'Coordenadas']
df_seleccionados = archivo_excel[columnas]

df_seleccionados.head()
# Out:
# Index(['#', 'Luz', 'Agua', 'Gas', 'Cloacas', 'Suelo', 'Contexto urbano',
#        'Permeabilidad', 'usd mt2', ' usd Total ', 'Superficie', 'Distrito',
#        'Latitud', 'Longuitud', 'Derecho de agua', 'Coordenadas'],
#       dtype='object')
#    # Luz Agua Gas Cloacas     Suelo           Contexto urbano Permeabilidad  \
# 0  1   1    1   1       0  Interfaz  Bº Privado en Desarrollo        Baldio
# 1  2   1    1   1       0  Interfaz  Bº Privado en Desarrollo        Baldio
# 2  3   1    1   1       0  Interfaz  Bº Privado en Desarrollo        Baldio
# 3  4   1    1   1       0  Interfaz  Bº Privado en Desarrollo        Baldio
# 4  6   1    1   1       0      Otro     Conexo a urbanización       Natural
#
#      usd mt2  usd Total   Superficie        Distrito  Latitud Longuitud  \
# 0  61.643836       27000         438  Mayor Drummond -33.0138  -68.8321
# 1  32.248607     11609.5         360           Otros -33.0603  -68.8672
# ...
